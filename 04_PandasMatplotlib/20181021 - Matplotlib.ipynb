# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt

matplotlib.__version__
# Out:
# '2.0.0'

# %%
x = np.linspace(-10, 10, 100)
y = x**2
plt.plot(x,y)
plt.show()

# %%
t = np.linspace(0, 2*np.pi, 100, endpoint=False)
x = 16 * np.sin(t)**3
y = 13*np.cos(t) -5 * np.cos(2*t) - 2* np.cos(134*t) - np.cos(4*t)
plt.fill(x,y,color="#FFc4ff")
plt.show()
